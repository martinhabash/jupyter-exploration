# %%
print("Hi, class!")
# Out:
# Hi, class!

# %% [markdown]
# # My First Jupyter Notebook
#
# This is my first Jupyter Notebook for ITAI 1378. In this lab, I practiced using Markdown and Python code cells in Jupyter Notebook.
